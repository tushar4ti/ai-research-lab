# %% [markdown]
# <a href="https://colab.research.google.com/github/tushar4ti/ai-research-lab/blob/main/252_16_002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Tushar Imran
#
#                                                Assignment —1
# ID: 252-16-002

# %% [markdown]
# **Problem 1:** Declare five variables: your name (str), age (int), height in meters (float), whether
# you are a student (bool), and a variable with no value (NoneType). Print all five values in a
# single print() statement.

# %%
name="Tushar Imran"
age=22
height=1.8
isStudent=True #I remembered that we should use camel case
value=None
print("My name is "+name+". I'm "+str(age)+" years old. My height is "+str(height)+" meters. I am a student and "+str(value)+" of my info is not "+str(isStudent))
#value gula string e convert na korle "+" operation kaj kore na tai convert kore nilam
# Out:
# My name is Tushar Imran. I'm 22 years old. My height is 1.8 meters. I am a student and None of my info is not True

# %% [markdown]
# **Problem 2:** Given x = &#39;42&#39;, y = 3.9, z = True - convert x to int, y to int (notice what happens to
# the decimal), and z to str. Print each converted value and verify its type using type().

# %%
x='42'
y=3.9
z=True
x=int(x)
print(x,type(x))
y=int(y) #y er absulate value ta thakbe sudhu. Float part baad jabe
print(y,type(y))
z=str(z)
print(z,type(z))
# Out:
# 42 <class 'int'>
# 3 <class 'int'>
# True <class 'str'>

# %% [markdown]
# **Problem 3:** Assign the values 10, 20, 30 to three variables a, b, c in a single line. Then swap a
# and c without using a temporary variable and print both before and after values.

# %%
a,b,c=10,20,30
print("Before: ", "a=", a, "c=" ,c)
a,c=c,a
print("After: ", "a=", a, "c=" ,c)
#hint dekhe oita likhlam hoye gelo
# Out:
# Before:  a= 10 c= 30
# After:  a= 30 c= 10

# %% [markdown]
# **Problem 4:** Show dynamic typing in action: create a variable x, assign an integer to it and print
# its type, then reassign a string to the same variable and print its type again, then reassign a float
# and print once more.

# %%
x=2
print(type(x))
x="002"
print(type(x))
x=2.0
print(type(x))
#Nice , eita C programming ba jei language gulay dataType+ variable name likhte hoy oigulay kaj korbe na
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %% [markdown]
# **Problem 5:** Try type-converting the following and print the result: bool(0), bool(&#39;&#39;), bool(&#39;hello&#39;),
# bool(99), int(True), int(False), float(&#39;3.14&#39;). Write one conversion per line with a comment
# explaining the output.

# %%
print(bool(0))    #O hole false r non zero hole true hobe
print(bool(""))   #string convert hoye kono space ba character retun kore nai tai false
print(bool("hello"))  #eitay string ache tai true
print(bool(99))     #number ache tai true
print(int(True))    #1number line e explain korchi
print(int(False))   # ||      ||  ||  ||      ||
print(float("3.14"))  #no change

# %% [markdown]
# **Problem 6:** Store any two integers in variables a and b. Print the result of all seven arithmetic
# operations (+, -, *, /, //, %, **) with a descriptive label for each line.

# %%
a, b = 13, 2
print("Addition:", a+b)
print("Subtraction:", a-b)
print("Multiplication:", a*b)
print("Division:", a/b)
print("Floor division:", a//b)
print("Modulus:", a%b)
print("Power:", a**b)
# Out:
# Addition: 15
# Subtraction: 11
# Multiplication: 26
# Division: 6.5
# Floor division: 6
# Modulus: 1
# Exponent: 169

# %% [markdown]
# **Problem 7:** Start with x = 100. Apply these augmented assignment operations in order and print
# x after each step: subtract 25, multiply by 2, floor-divide by 3, take modulus with 7, raise to
# power 2.

# %%
x=100
print(x)
x-=25
print(x)
x*=2
print(x)
x//=3
print(x)
x%=7
print(x)
# Out:
# 100
# 75
# 150
# 50
# 1

# %% [markdown]
# **Problem 8:** Given a = 15, b = 15, c = [1,2], d = [1,2] - print the result of: a == b, a is b, c == d, c
# is d. Then explain in a comment why &#39;is&#39; and &#39;==&#39; give different results for the lists.

# %%
a,b =15,15
c=[1,2]
d=[1,2]
print(a == b)
print(a is b)
print(c == d) #eita value match korteche
print(c is d) #eita value jei memory location e store kora oi location 2 ta same kina check korteche
# Out:
# True
# True
# True
# False

# %% [markdown]
# **Problem 9:** Write expressions using logical operators to check: (1) a number is between 10 and
# 50 (inclusive), (2) a string is either &#39;yes&#39; or &#39;no&#39;, (3) a number is NOT divisible by 2. Test each
# with sample values and print True/False.

# %%
#1
x=19
if(x>=10 and x<=50):
    print("True")
else:
    print("False")
# Out:
# True

# %%
#2
text=input("Enter a string: ")
text=text.lower() #sob text lowercase kore nilam better validation er jonno
if(text=="yes" or text=="no"):
    print("True")
else:
    print("False")
# Out:
# Enter a string: yeS
# True

# %%
#3
num=int(input("Enter a number: "))
if(num%2!=0):
    print("True") #divisible na hole Ture hobe
else:
    print("False")
# Out:
# Enter a number: 40
# False

# %% [markdown]
# **Problem 10:**  Check membership using 'in' and 'not in': (1) is 'py' inside 'python'? (2) is 'z' not in 'python'? (3) is 7 in the list [1, 3, 5, 7, 9]? (4) is 4 not in the same list? Print each result.

# %%
#1&2
a="python"
print('py' in a)
print('z' not in a)
# Out:
# True
# True

# %%
#3&4
li=[1,3,5,7,9]
print(3 in li)
print(4 not in li)
# Out:
# True
# True

# %% [markdown]
# **Problem 11:**  Take the string s = '  python programming  '. In separate print statements, show: the stripped version, stripped + upper(), stripped + title(), stripped + replace('python', 'data'), and the length of the stripped string.

# %%
s = " python programming "
print(s)
print(len(s))
print(s.strip())
print(len(s.strip()))
print(s.strip().upper())
print(s.strip().title())
print(s.strip().replace("python","data"))
print(len(s.strip())) #len 16 ta na hoye 18 ta holo karon data python die replace kore sudhu print koraichi, store korai nai kothau
a=s.strip().replace("python","data")
print(len(a))#eibar 16 dekhabe
# Out:
#  python programming
# 20
# python programming
# 18
# PYTHON PROGRAMMING
# Python Programming
# data programming
# 18
# 16

# %% [markdown]
# **Problem 12:**  Given text = 'Data,Science,Machine,Learning' - split it into a list, print the list, print the second element, print the total number of elements, then join the list back with ' → ' as separator.

# %%
text="Data,Science,Machine,Learning"
li=text.split(",")
print(li)
print(li[1]) #2nd element er jonno index 1 hobe karon 0 theke start
print(len(li)) #number of element dekhabe
print(" → ".join(li)) #sinle string
print(li) #join kora ta to r store kori nai tai same ache
# Out:
# ['Data', 'Science', 'Machine', 'Learning']
# Science
# 4
# Data → Science → Machine → Learning
# ['Data', 'Science', 'Machine', 'Learning']

# %% [markdown]
# **Problem 13:**  Given sentence = 'Hello World Python' - use slicing to print: the first 5 characters, the last 6 characters, every second character, and the entire string reversed.

# %%
given="Hello World Python"
print(given[0:6])
print(given[-6:])
print(given[::2])
print(given[::-1])
# Out:
# Hello
# Python
# HloWrdPto
# nohtyP dlroW olleH

# %% [markdown]
# **Problem 14:**  For the string word = 'Banana' - print the result of: find('a'), count('a'), startswith('Ba'), endswith('na'), isdigit(). Then check if '12345'.isdigit() is different from '123a5'.isdigit().

# %%
w="Banana"
print(w.find("a")) #koto number index e paiche oita return korteche
print(w.count("a"))
print(w.count("n"))
print(w.startswith("Ba"))
print(w.endswith("na"))
print(w.isdigit())
print(("12345".isdigit()) is ("123a5".isdigit())) #2ta diffrent tai false
# Out:
# 1
# 3
# 2
# True
# True
# False
# False

# %% [markdown]
# **Problem 15:**  Create three variables: product = 'Laptop', price = 75000.5, discount = 10. Print a formatted line using all three string formatting styles (f-string, .format(), % operator) showing: 'Product: Laptop | Price: 75000.50 | Discount: 10%'.

# %%
product="Laptop"
price=75000.5
discount=10
print(f"Product: {product} | Price: {price:.2f} | Discount: {discount}%")
print("Product: {} | Price: {:.2f} | Discount: {}%".format(product,price,discount))
print("Product: %s | Price: %.2f | Discount: %d%%" % (product,price,discount))
#eita ai er help nie korchi
# Out:
# Product: Laptop | Price: 75000.50 | Discount: 10%
# Product: Laptop | Price: 75000.50 | Discount: 10%
# Product: Laptop | Price: 75000.50 | Discount: 10%

# %% [markdown]
# **Problem 16:**  Write a program that takes the user's name and birth year as input. Calculate their approximate age (current year - birth year) and print: 'Hello [name]! You are approximately [age] years old.'

# %%
name=input("Enter your name : ")
age=2026-(int(input("Enter your birth year : ")))
print(f"Hello {name}!! You are approximately {age} years old.")
# Out:
# Enter your name : Tushar
# Enter your birth year : 2004
# Hello Tushar!! You are approximately 22 years old.

# %% [markdown]
# **Problem 17:**  Build a simple area calculator. Ask the user to enter length and width (as floats). Calculate area and perimeter of the rectangle. Print both results formatted to 2 decimal places with descriptive labels.

# %%
length=float(input("Enter length : "))
width=float(input("Enter width : "))
area=length*width
perimeter=2*(length+width)
print(f"Area: {area:.2f}")
print(f"Perimeter: {perimeter:.2f}")

# %% [markdown]
# **Problem 18:**  Take a score (0 - 100) from the user and print a grade using if-elif-else: 90–100 → 'A+', 80–89 → 'A', 60–79 → 'B', 40–59 → 'C', below 40 → 'F'. Also print 'Pass' or 'Fail' based on score >= 40.

# %%
mark=int(input("Enter your mark : "))
if(mark>=0 and mark<=100):
  if(mark>=90 and mark<=100):
    grade="A+"
  elif(mark>=80 and mark<=89):
      grade="A"
  elif(mark>=60 and mark<=79):
      grade="B"
  elif(mark>=40 and mark<=59):
      grade="C"
  else:
      grade="F"
else:
  print("Invalid marks")
if(mark>=0 and mark<=100):
  if(grade=="F"):
    print("Fail")
  else:
    print("Pass")
    print(f"Grade: {grade}")
# Out:
# Enter your mark : 30
# Fail

# %% [markdown]
# **Problem 19:**  Write a login system. Store a correct username and password in two variables. Take username and password input from the user. Using nested if-else: if username matches → check password → print 'Access Granted' or 'Wrong Password'; if username doesn't match → print 'User Not Found'.

# %%
correct_user, correct_pass = "Tushar", "25216002"
user = input("Username: ")
pas = input("Password: ")
if user == correct_user:
    if pas == correct_pass:
        print("Access Granted")
    else:
        print("Wrong Password")
else:
    print("User Not Found")
# Out:
# Username: Tushar
# Password: 25216002
# Access Granted

# %% [markdown]
# **Problem 20:**  Take any number from the user. Using a single line ternary expression, print whether it is 'Positive', 'Negative', or 'Zero'. Then separately, using nested if-elif-else, also check if the number is even or odd (only if it is not zero).

# %%
#1
x=int(input("Enter a number : "))
print("Positive" if x > 0 else ("Negative" if x < 0 else "Zero"))
# Out:
# Enter a number : 25
# Positive

# %%
#2
x=int(input("Enter a number : "))
if(x!=0):
  if(x%2==0):
    print("Even")
  else:
    print("Odd")
else:
  print("zero")
# Out:
# Enter a number : 132312
# Even
